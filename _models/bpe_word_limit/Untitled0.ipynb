# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd gdrive/My Drive/inz/offensive-language-semeval
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive/inz/offensive-language-semeval'
# /content

# %%
cd gdrive/My Drive/inz
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive/inz'
# /content

# %%
cd drive/My Drive/inz
# Out:
# /content/drive/My Drive/inz

# %%
cd offensive-language-semeval/
# Out:
# /content/drive/My Drive/inz/offensive-language-semeval

# %%
! git checkout -b ninesix_and_word_limit
# Out:
# M	rest_models/manage.py
# M	scripts/build_test.py
# M	text_clsf_lib/data_preparation/data_extracton.py
# M	text_clsf_lib/models/eval/model_evaluations.py
# M	utils/files_io.py
# Switched to a new branch 'ninesix_and_word_limit'

# %%
git add _models/
